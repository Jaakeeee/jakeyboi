# %% [markdown]
# # Assignment: Libraries
#
# This problem set aims to develop your ability to use non-standard libraries such as NumPy, Pandas, Matplotlib, and requests.
#
# Please follow all instructions precisely.

# %% [markdown]
# ## Prerequisite: Install libraries
#
# To do this assignment, you need to have a few libraries installed. You already know how to install libraries in a basic Python virtual environment. In Anaconda, it is even easier.
#
# Install the following libraries:
# 1. Pandas
# 2. Requests
# 3. Matplotlib
#
# Follow this tutorial to install external libraries for your Jupyter notebook using the Anaconda Navigator.
#
# https://www.tutorialspoint.com/add-packages-to-anaconda-environment-in-python
#
# Once you are done, run the following cell. If it does nothing (i.e., if it throws no errors), then you may proceed.

# %%
# NON-EDITABLE CODE CELL
# You may run this cell, but do not edit it.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %% [markdown]
# ## Note
#
# 1. There is a good chance that you will have to look up how to do things using these libraries. This is fine. Just credit your sources appropriately.

# %% [markdown]
# ## Problem 1: Association Rules

# %% [markdown]
# ### Context
#
# You are a data consultant for a medium-sized grocery. Your job is to help the grocery's marketing and sales team identify the most frequent purchases of customers.

# %% [markdown]
# ### 1.1
#
# Read the file `sample order basket.csv` into a Pandas DataFrame called `df`.

# %%
# CODE CELL

# CODE START
filename = 'sample order basket.csv'
df = pd.read_csv(filename)
# CODE END
df.head()

# %% [markdown]
# ### 1.2
#
# Create a "binary table" using a Pandas DataFrame. Save the DataFrame in a variable called `binary_table`.
#
# The specifications of the binary table are as follows:
# 1. The data in the binary table is based on the order log contained in `df`.
# 2. The index values of the binary table are the unique order IDs contained in the sales logs. These are arranged in ascending numerical order. Format the values as `int64`.
# 3. The column values of the binary table are the unique products contained in the sales logs. These are arranged in alphabetical order. Format the values as `object`.
# 4. The values of the binary table are either 0 or 1. A value will be 1 if the respective product is present in the respective order, and it will be 0 if the respective product is not present in the respective order. So, for example: if Order 5 ordered an apple, then the cell at row 5, column apple will have the value 1, and every other cell at row 5 will have the value 0.

# %%
# CODE CELL

# CODE START

orders_np = np.int64(df['OrderNum'].unique())
unique_products = np.array(sorted(df['Product'].unique()), dtype = object)
binary_table = []

for i in range(len(orders_np)):
    order_dict = {}
    order_dict.setdefault('OrderNum',orders_np[i])
    estimateorder = df.loc[df['OrderNum']==orders_np[i],:]
    fixed_orders = sorted(np.array(estimateorder['Product']))
    order_value = 0
    product_value = 0
    
    while product_value < len(unique_products):
        if order_value > len(fixed_orders)-1:
            order_dict.setdefault(unique_products[product_value],0)
            product_value += 1
        else:
            product_value_counter = 0
            if fixed_orders[order_value] != unique_products[product_value]:
                order_dict.setdefault(unique_products[product_value], product_value_counter)
                product_value += 1
            else:
                product_value_counter = 1
                order_dict.setdefault(unique_products[product_value], product_value_counter)
                order_value += 1
                product_value += 1
                
    binary_table.append(order_dict)
    
print(binary_table)
binary_table = pd.DataFrame(binary_table)

# CODE END

# %% [markdown]
# ### 1.3
#
# Using `binary_table`, create a report. Store this report in a Pandas DataFrame called `report`.
#
# The specifications of the report are as follows:
# 1. The data in the report is based on the data in `binary_table`.
# 2. The index values of `report` are simply the defaults (i.e., counting up from 0 to whatever number).
# 3. `report` has two columns: `combination` and `count`. The `combination` column will contain tuples that describe an order combination (e.g., ("apple", "eggplant")). Format the `combination` column as `object`. The `count` column will contain an integer value describing the number of times that this combination appeared in the list of orders. Format the `count` column as `int64`.
# 4. Sort `reports` by `count` in descending order. The order of combinations within each count bracket does not matter.
#
# You may use any standard library from Python 3.8 that you feel is necessary to complete this item. (This just means that you can use any standard Python library as long as it was in Python 3.8).

# %%
# CODE CELL

# CODE START
orders_np = np.int64(df["OrderNum"].unique())
unique_products = np.array(sorted(df["Product"].unique()), dtype = object)

combination = {}

for i in range(len(binary_table["OrderNum"])):
    order_list =[]
    order_with_product = binary_table.loc[binary_table["OrderNum"]==orders_np[i],:]
    for product in range(len(unique_products)):
        item = unique_products[product]
        len_of_product = np.array(order_with_product[item])
        if len_of_product[0]==1:
            order_list.append(item)
    combination.setdefault(tuple(order_list),0)
    combination[tuple(order_list)]+=1
combinations_sorted = list(combination.items())
combinations_sorted.sort(key = lambda x: x[1], reverse=True)
report = pd.DataFrame([ {"Combination" : value[0], "Count" : np.int64(value[1])} for value in combinations_sorted ])
report.head()
# CODE END

# %% [markdown]
# ## Problem 2: A Plot of the International Space Station's Location

# %% [markdown]
# We will only be checking the final output of this problem.
#
# ### Context
#
# You are a budding data scientist aiming to try your new tools on real-world data. As a pet project, you have decided that you want to try plotting the latitude and longitude positions of the International Space Station on a chart.
#
# An "application programming interface" (API) is an interface (i.e., a point of connection/use) that a program offers to other pieces of software. APIs are how modern computer programs interact. To massively oversimplify the concept, modern applications send and receive HTTP requests and JSON-formatted data to talk to each other.
#
# We will be using the ISS position data API hosted at http://open-notify.org/Open-Notify-API/ISS-Location-Now/ for this item.
#
# You are expected to read the documentation of this API for this item.

# %% [markdown]
# ### 2.1
#
# Use the `requests` library and the `time` library to collect position data of the ISS at intervals of 10 seconds over the course of 30 minutes by sending GET requests to the ISS API endpoint.
#
# The specifications of this problem are as follows:
# 1. Send a GET request to the ISS API endpoint once every 10 seconds for 30 minutes.
# 2. Each time you send a GET request, append the returned data to a list called `iss_data`.
# 3. Save all the data to a file called `iss-data.json` so that you do not lose it. You may do this every time you get a request if you wish.
# 4. Do not modify the returned data per GET request.
# 5. The final file `iss-data.json` should contain roughly 180 data points.
#
# We will not be strict about the time intervals. We will only look at the chart that you produce from your data.

# %%
# CODE CELL

# CODE START
iss_data = []
import requests
import time
import json
from requests.exceptions import HTTPError
import datetime as dt
time_now = dt.datetime.now()
time_in_30_min = time_now + dt.timedelta(minutes=30)
while time_now < time_in_30_min:
    try:
        response = requests.get('http://api.open-notify.org/iss-now.json')
        response.raise_for_status()
        print(response.json())
        print(time_now)
        print()
        iss_data.append(response.json())
    except HTTPError as http_err:
        print(f'HTTP error occurred: {http_err}')
    except Exception as err:
        print(f'Other error occurred: {err}')
    time.sleep(10)
    time_now = dt.datetime.now()
    
with open('iss-data.json', 'w') as f:
    json.dump(iss_data, f)
# CODE END
# Out:
# {'timestamp': 1628263768, 'iss_position': {'latitude': '-29.1600', 'longitude': '111.6629'}, 'message': 'success'}
# 2021-08-06 23:29:27.281053
#
# {'timestamp': 1628263778, 'iss_position': {'latitude': '-29.6136', 'longitude': '112.1491'}, 'message': 'success'}
# 2021-08-06 23:29:37.636239
#
# {'timestamp': 1628263788, 'iss_position': {'latitude': '-30.0876', 'longitude': '112.6646'}, 'message': 'success'}
# 2021-08-06 23:29:47.988646
#
# {'timestamp': 1628263798, 'iss_position': {'latitude': '-30.5367', 'longitude': '113.1606'}, 'message': 'success'}
# 2021-08-06 23:29:58.340194
#
# {'timestamp': 1628263809, 'iss_position': {'latitude': '-31.0060', 'longitude': '113.6869'}, 'message': 'success'}
# 2021-08-06 23:30:08.684149
#
# {'timestamp': 1628263819, 'iss_position': {'latitude': '-31.4727', 'longitude': '114.2188'}, 'message': 'success'}
# 2021-08-06 23:30:19.064064
#
# {'timestamp': 1628263830, 'iss_position': {'latitude': '-31.9368', 'longitude': '114.7564'}, 'message': 'success'}
# 2021-08-06 23:30:29.427203
#
# {'timestamp': 1628263840, 'iss_position': {'latitude': '-32.3762', 'longitude': '115.2738'}, 'message': 'success'}
# 2021-08-06 23:30:39.776473
#
# {'timestamp': 1628263850, 'iss_position': {'latitude': '-32.8349', 'longitude': '115.8230'}, 'message': 'success'}
# 2021-08-06 23:30:50.133740
#
# {'timestamp': 1628263861, 'iss_position': {'latitude': '-33.2908', 'longitude': '116.3783'}, 'message': 'success'}
# 2021-08-06 23:31:00.515014
#
# {'timestamp': 1628263871, 'iss_position': {'latitude': '-33.7223', 'longitude': '116.9130'}, 'message': 'success'}
# 2021-08-06 23:31:10.868085
#
# {'timestamp': 1628263881, 'iss_position': {'latitude': '-34.1724', 'longitude': '117.4806'}, 'message': 'success'}
# 2021-08-06 23:31:21.246756
#
# {'timestamp': 1628263892, 'iss_position': {'latitude': '-34.6193', 'longitude': '118.0547'}, 'message': 'success'}
# 2021-08-06 23:31:31.607634
#
# {'timestamp': 1628263902, 'iss_position': {'latitude': '-35.0422', 'longitude': '118.6078'}, 'message': 'success'}
# 2021-08-06 23:31:41.959428
#
# {'timestamp': 1628263912, 'iss_position': {'latitude': '-35.4829', 'longitude': '119.1952'}, 'message': 'success'}
# 2021-08-06 23:31:52.303692
#
# {'timestamp': 1628263923, 'iss_position': {'latitude': '-35.9204', 'longitude': '119.7895'}, 'message': 'success'}
# 2021-08-06 23:32:02.652875
#
# {'timestamp': 1628263933, 'iss_position': {'latitude': '-36.3546', 'longitude': '120.3910'}, 'message': 'success'}
# 2021-08-06 23:32:13.009521
#
# {'timestamp': 1628263943, 'iss_position': {'latitude': '-36.7646', 'longitude': '120.9704'}, 'message': 'success'}
# 2021-08-06 23:32:23.469509
#
# {'timestamp': 1628263954, 'iss_position': {'latitude': '-37.1916', 'longitude': '121.5859'}, 'message': 'success'}
# 2021-08-06 23:32:33.856668
#
# {'timestamp': 1628263964, 'iss_position': {'latitude': '-37.6149', 'longitude': '122.2088'}, 'message': 'success'}
# 2021-08-06 23:32:44.207298
#
# {'timestamp': 1628263974, 'iss_position': {'latitude': '-38.0144', 'longitude': '122.8091'}, 'message': 'success'}
# 2021-08-06 23:32:54.590950
#
# {'timestamp': 1628263985, 'iss_position': {'latitude': '-38.4302', 'longitude': '123.4470'}, 'message': 'success'}
# 2021-08-06 23:33:04.941358
#
# {'timestamp': 1628263995, 'iss_position': {'latitude': '-38.8421', 'longitude': '124.0929'}, 'message': 'success'}
# 2021-08-06 23:33:15.334185
#
# {'timestamp': 1628264005, 'iss_position': {'latitude': '-39.2304', 'longitude': '124.7153'}, 'message': 'success'}
# 2021-08-06 23:33:25.695587
#
# {'timestamp': 1628264016, 'iss_position': {'latitude': '-39.6340', 'longitude': '125.3769'}, 'message': 'success'}
# 2021-08-06 23:33:36.053080
#
# {'timestamp': 1628264026, 'iss_position': {'latitude': '-40.0334', 'longitude': '126.0466'}, 'message': 'success'}
# 2021-08-06 23:33:46.442426
#
# {'timestamp': 1628264037, 'iss_position': {'latitude': '-40.4282', 'longitude': '126.7248'}, 'message': 'success'}
# 2021-08-06 23:33:56.790884
#
# {'timestamp': 1628264047, 'iss_position': {'latitude': '-40.8001', 'longitude': '127.3786'}, 'message': 'success'}
# 2021-08-06 23:34:07.141644
#
# {'timestamp': 1628264058, 'iss_position': {'latitude': '-41.1859', 'longitude': '128.0732'}, 'message': 'success'}
# 2021-08-06 23:34:17.494177
#
# {'timestamp': 1628264068, 'iss_position': {'latitude': '-41.5671', 'longitude': '128.7768'}, 'message': 'success'}
# 2021-08-06 23:34:27.885860
#
# {'timestamp': 1628264078, 'iss_position': {'latitude': '-41.9254', 'longitude': '129.4549'}, 'message': 'success'}
# 2021-08-06 23:34:38.238788
#
# {'timestamp': 1628264089, 'iss_position': {'latitude': '-42.2968', 'longitude': '130.1756'}, 'message': 'success'}
# 2021-08-06 23:34:48.617367
#
# {'timestamp': 1628264099, 'iss_position': {'latitude': '-42.6630', 'longitude': '130.9053'}, 'message': 'success'}
# 2021-08-06 23:34:58.962090
#
# {'timestamp': 1628264109, 'iss_position': {'latitude': '-43.0069', 'longitude': '131.6089'}, 'message': 'success'}
# 2021-08-06 23:35:09.344498
#
# {'timestamp': 1628264120, 'iss_position': {'latitude': '-43.3627', 'longitude': '132.3566'}, 'message': 'success'}
# 2021-08-06 23:35:19.721905
#
# {'timestamp': 1628264130, 'iss_position': {'latitude': '-43.7130', 'longitude': '133.1135'}, 'message': 'success'}
# 2021-08-06 23:35:30.069451
#
# {'timestamp': 1628264140, 'iss_position': {'latitude': '-44.0413', 'longitude': '133.8430'}, 'message': 'success'}
# 2021-08-06 23:35:40.428571
#
# {'timestamp': 1628264151, 'iss_position': {'latitude': '-44.3803', 'longitude': '134.6181'}, 'message': 'success'}
# 2021-08-06 23:35:50.809699
#
# {'timestamp': 1628264161, 'iss_position': {'latitude': '-44.7134', 'longitude': '135.4027'}, 'message': 'success'}
# 2021-08-06 23:36:01.194073
#
# {'timestamp': 1628264172, 'iss_position': {'latitude': '-45.0405', 'longitude': '136.1968'}, 'message': 'success'}
# 2021-08-06 23:36:11.579112
#
# {'timestamp': 1628264182, 'iss_position': {'latitude': '-45.3462', 'longitude': '136.9619'}, 'message': 'success'}
# 2021-08-06 23:36:21.944975
#
# {'timestamp': 1628264192, 'iss_position': {'latitude': '-45.6610', 'longitude': '137.7747'}, 'message': 'success'}
# 2021-08-06 23:36:32.294541
#
# {'timestamp': 1628264203, 'iss_position': {'latitude': '-45.9693', 'longitude': '138.5971'}, 'message': 'success'}
# 2021-08-06 23:36:42.673018
#
# {'timestamp': 1628264213, 'iss_position': {'latitude': '-46.2709', 'longitude': '139.4290'}, 'message': 'success'}
# 2021-08-06 23:36:53.061659
#
# {'timestamp': 1628264223, 'iss_position': {'latitude': '-46.5519', 'longitude': '140.2302'}, 'message': 'success'}
# 2021-08-06 23:37:03.452144
#
# {'timestamp': 1628264234, 'iss_position': {'latitude': '-46.8403', 'longitude': '141.0809'}, 'message': 'success'}
# 2021-08-06 23:37:13.806124
#
# {'timestamp': 1628264244, 'iss_position': {'latitude': '-47.1215', 'longitude': '141.9411'}, 'message': 'success'}
# 2021-08-06 23:37:24.158443
#
# {'timestamp': 1628264254, 'iss_position': {'latitude': '-47.3828', 'longitude': '142.7692'}, 'message': 'success'}
# 2021-08-06 23:37:34.536747
#
# {'timestamp': 1628264265, 'iss_position': {'latitude': '-47.6499', 'longitude': '143.6481'}, 'message': 'success'}
# 2021-08-06 23:37:44.884926
#
# {'timestamp': 1628264276, 'iss_position': {'latitude': '-47.9338', 'longitude': '144.6210'}, 'message': 'success'}
# 2021-08-06 23:37:55.253926
#
# {'timestamp': 1628264286, 'iss_position': {'latitude': '-48.1732', 'longitude': '145.4762'}, 'message': 'success'}
# 2021-08-06 23:38:06.641866
#
# {'timestamp': 1628264297, 'iss_position': {'latitude': '-48.4170', 'longitude': '146.3830'}, 'message': 'success'}
# 2021-08-06 23:38:17.026927
#
# {'timestamp': 1628264307, 'iss_position': {'latitude': '-48.6529', 'longitude': '147.2987'}, 'message': 'success'}
# 2021-08-06 23:38:27.393913
#
# {'timestamp': 1628264318, 'iss_position': {'latitude': '-48.8807', 'longitude': '148.2234'}, 'message': 'success'}
# 2021-08-06 23:38:37.786799
#
# {'timestamp': 1628264328, 'iss_position': {'latitude': '-49.0900', 'longitude': '149.1120'}, 'message': 'success'}
# 2021-08-06 23:38:48.162105
#
# {'timestamp': 1628264339, 'iss_position': {'latitude': '-49.3018', 'longitude': '150.0535'}, 'message': 'success'}
# 2021-08-06 23:38:58.519756
#
# {'timestamp': 1628264349, 'iss_position': {'latitude': '-49.5050', 'longitude': '151.0036'}, 'message': 'success'}
# 2021-08-06 23:39:08.894541
#
# {'timestamp': 1628264359, 'iss_position': {'latitude': '-49.6906', 'longitude': '151.9157'}, 'message': 'success'}
# 2021-08-06 23:39:19.272171
# {'timestamp': 1628264370, 'iss_position': {'latitude': '-49.8769', 'longitude': '152.8811'}, 'message': 'success'}
# 2021-08-06 23:39:29.675475
#
# {'timestamp': 1628264380, 'iss_position': {'latitude': '-50.0544', 'longitude': '153.8542'}, 'message': 'success'}
# 2021-08-06 23:39:40.034814
#
# {'timestamp': 1628264391, 'iss_position': {'latitude': '-50.2230', 'longitude': '154.8346'}, 'message': 'success'}
# 2021-08-06 23:39:50.413731
#
# {'timestamp': 1628264401, 'iss_position': {'latitude': '-50.3750', 'longitude': '155.7749'}, 'message': 'success'}
# 2021-08-06 23:40:00.803794
#
# {'timestamp': 1628264411, 'iss_position': {'latitude': '-50.5258', 'longitude': '156.7692'}, 'message': 'success'}
# 2021-08-06 23:40:11.156302
#
# {'timestamp': 1628264422, 'iss_position': {'latitude': '-50.6672', 'longitude': '157.7696'}, 'message': 'success'}
# 2021-08-06 23:40:21.560010
#
# {'timestamp': 1628264432, 'iss_position': {'latitude': '-50.7931', 'longitude': '158.7281'}, 'message': 'success'}
# 2021-08-06 23:40:31.923002
#
# {'timestamp': 1628264442, 'iss_position': {'latitude': '-50.9161', 'longitude': '159.7400'}, 'message': 'success'}
# 2021-08-06 23:40:42.319807
#
# {'timestamp': 1628264453, 'iss_position': {'latitude': '-51.0295', 'longitude': '160.7574'}, 'message': 'success'}
# 2021-08-06 23:40:52.693963
#
# {'timestamp': 1628264463, 'iss_position': {'latitude': '-51.1332', 'longitude': '161.7797'}, 'message': 'success'}
# 2021-08-06 23:41:03.049579
#
# {'timestamp': 1628264473, 'iss_position': {'latitude': '-51.2229', 'longitude': '162.7577'}, 'message': 'success'}
# 2021-08-06 23:41:13.401838
#
# {'timestamp': 1628264484, 'iss_position': {'latitude': '-51.3075', 'longitude': '163.7885'}, 'message': 'success'}
# 2021-08-06 23:41:23.757314
#
# {'timestamp': 1628264494, 'iss_position': {'latitude': '-51.3822', 'longitude': '164.8231'}, 'message': 'success'}
# 2021-08-06 23:41:34.123769
#
# {'timestamp': 1628264504, 'iss_position': {'latitude': '-51.4441', 'longitude': '165.8115'}, 'message': 'success'}
# 2021-08-06 23:41:44.464536
#
# {'timestamp': 1628264515, 'iss_position': {'latitude': '-51.4994', 'longitude': '166.8521'}, 'message': 'success'}
# 2021-08-06 23:41:54.819515
#
# {'timestamp': 1628264525, 'iss_position': {'latitude': '-51.5446', 'longitude': '167.8952'}, 'message': 'success'}
# 2021-08-06 23:42:05.176354
#
# {'timestamp': 1628264535, 'iss_position': {'latitude': '-51.5783', 'longitude': '168.8903'}, 'message': 'success'}
# 2021-08-06 23:42:15.557069
#
# {'timestamp': 1628264546, 'iss_position': {'latitude': '-51.6039', 'longitude': '169.9367'}, 'message': 'success'}
# 2021-08-06 23:42:25.908904
#
# {'timestamp': 1628264556, 'iss_position': {'latitude': '-51.6193', 'longitude': '170.9840'}, 'message': 'success'}
# 2021-08-06 23:42:36.410212
#
# {'timestamp': 1628264567, 'iss_position': {'latitude': '-51.6246', 'longitude': '172.0320'}, 'message': 'success'}
# 2021-08-06 23:42:46.784814
#
# {'timestamp': 1628264577, 'iss_position': {'latitude': '-51.6202', 'longitude': '173.0300'}, 'message': 'success'}
# 2021-08-06 23:42:57.158725
#
# {'timestamp': 1628264588, 'iss_position': {'latitude': '-51.6057', 'longitude': '174.0774'}, 'message': 'success'}
# 2021-08-06 23:43:07.540329
#
# {'timestamp': 1628264598, 'iss_position': {'latitude': '-51.5811', 'longitude': '175.1237'}, 'message': 'success'}
# 2021-08-06 23:43:17.924592
#
# {'timestamp': 1628264608, 'iss_position': {'latitude': '-51.5482', 'longitude': '176.1190'}, 'message': 'success'}
# 2021-08-06 23:43:28.280968
#
# {'timestamp': 1628264619, 'iss_position': {'latitude': '-51.5039', 'longitude': '177.1622'}, 'message': 'success'}
# 2021-08-06 23:43:38.646004
#
# {'timestamp': 1628264629, 'iss_position': {'latitude': '-51.4495', 'longitude': '178.2032'}, 'message': 'success'}
# 2021-08-06 23:43:49.007997
#
# {'timestamp': 1628264640, 'iss_position': {'latitude': '-51.3851', 'longitude': '179.2413'}, 'message': 'success'}
# 2021-08-06 23:43:59.357757
#
# {'timestamp': 1628264650, 'iss_position': {'latitude': '-51.3146', 'longitude': '-179.7730'}, 'message': 'success'}
# 2021-08-06 23:44:09.737051
#
# {'timestamp': 1628264660, 'iss_position': {'latitude': '-51.2309', 'longitude': '-178.7417'}, 'message': 'success'}
# 2021-08-06 23:44:20.081448
#
# {'timestamp': 1628264671, 'iss_position': {'latitude': '-51.1373', 'longitude': '-177.7147'}, 'message': 'success'}
# 2021-08-06 23:44:30.469564
#
# {'timestamp': 1628264681, 'iss_position': {'latitude': '-51.0392', 'longitude': '-176.7409'}, 'message': 'success'}
# 2021-08-06 23:44:40.829114
#
# {'timestamp': 1628264691, 'iss_position': {'latitude': '-50.9266', 'longitude': '-175.7228'}, 'message': 'success'}
# 2021-08-06 23:44:51.228778
#
# {'timestamp': 1628264702, 'iss_position': {'latitude': '-50.8045', 'longitude': '-174.7102'}, 'message': 'success'}
# 2021-08-06 23:45:01.618984
#
# {'timestamp': 1628264712, 'iss_position': {'latitude': '-50.6729', 'longitude': '-173.7033'}, 'message': 'success'}
# 2021-08-06 23:45:12.010422
#
# {'timestamp': 1628264722, 'iss_position': {'latitude': '-50.5388', 'longitude': '-172.7502'}, 'message': 'success'}
# 2021-08-06 23:45:22.364774
#
# {'timestamp': 1628264733, 'iss_position': {'latitude': '-50.3889', 'longitude': '-171.7555'}, 'message': 'success'}
# 2021-08-06 23:45:32.746888
#
# {'timestamp': 1628264743, 'iss_position': {'latitude': '-50.2298', 'longitude': '-170.7676'}, 'message': 'success'}
# 2021-08-06 23:45:43.132041
#
# {'timestamp': 1628264753, 'iss_position': {'latitude': '-50.0699', 'longitude': '-169.8333'}, 'message': 'success'}
# 2021-08-06 23:45:53.510723
#
# {'timestamp': 1628264764, 'iss_position': {'latitude': '-49.8932', 'longitude': '-168.8596'}, 'message': 'success'}
# 2021-08-06 23:46:03.866736
#
# {'timestamp': 1628264774, 'iss_position': {'latitude': '-49.7076', 'longitude': '-167.8933'}, 'message': 'success'}
# 2021-08-06 23:46:14.222566
#
# {'timestamp': 1628264784, 'iss_position': {'latitude': '-49.5228', 'longitude': '-166.9805'}, 'message': 'success'}
# 2021-08-06 23:46:24.571595
#
# {'timestamp': 1628264795, 'iss_position': {'latitude': '-49.3203', 'longitude': '-166.0298'}, 'message': 'success'}
# 2021-08-06 23:46:34.925943
#
# {'timestamp': 1628264805, 'iss_position': {'latitude': '-49.1092', 'longitude': '-165.0872'}, 'message': 'success'}
# 2021-08-06 23:46:45.313785
#
# {'timestamp': 1628264816, 'iss_position': {'latitude': '-48.8899', 'longitude': '-164.1533'}, 'message': 'success'}
# 2021-08-06 23:46:55.702214
#
# {'timestamp': 1628264826, 'iss_position': {'latitude': '-48.6734', 'longitude': '-163.2721'}, 'message': 'success'}
# 2021-08-06 23:47:06.081290
#
# {'timestamp': 1628264836, 'iss_position': {'latitude': '-48.4382', 'longitude': '-162.3555'}, 'message': 'success'}
# 2021-08-06 23:47:16.475605
#
# {'timestamp': 1628264847, 'iss_position': {'latitude': '-48.1951', 'longitude': '-161.4477'}, 'message': 'success'}
# 2021-08-06 23:47:26.849795
#
# {'timestamp': 1628264857, 'iss_position': {'latitude': '-47.9563', 'longitude': '-160.5918'}, 'message': 'success'}
# 2021-08-06 23:47:37.211767
#
# {'timestamp': 1628264868, 'iss_position': {'latitude': '-47.6981', 'longitude': '-159.7022'}, 'message': 'success'}
# 2021-08-06 23:47:47.598550
#
# {'timestamp': 1628264878, 'iss_position': {'latitude': '-47.4324', 'longitude': '-158.8219'}, 'message': 'success'}
# 2021-08-06 23:47:57.980179
#
# {'timestamp': 1628264889, 'iss_position': {'latitude': '-47.1593', 'longitude': '-157.9509'}, 'message': 'success'}
# 2021-08-06 23:48:08.348347
#
# {'timestamp': 1628264899, 'iss_position': {'latitude': '-46.8926', 'longitude': '-157.1302'}, 'message': 'success'}
# 2021-08-06 23:48:18.740369
#
# {'timestamp': 1628264909, 'iss_position': {'latitude': '-46.6056', 'longitude': '-156.2779'}, 'message': 'success'}
# 2021-08-06 23:48:29.094358
#
# {'timestamp': 1628264920, 'iss_position': {'latitude': '-46.3116', 'longitude': '-155.4352'}, 'message': 'success'}
# 2021-08-06 23:48:39.469668
#
# {'timestamp': 1628264930, 'iss_position': {'latitude': '-46.0253', 'longitude': '-154.6413'}, 'message': 'success'}
# 2021-08-06 23:48:49.853374
#
# {'timestamp': 1628264940, 'iss_position': {'latitude': '-45.7182', 'longitude': '-153.8172'}, 'message': 'success'}
# 2021-08-06 23:49:00.207289
#
# {'timestamp': 1628264951, 'iss_position': {'latitude': '-45.4046', 'longitude': '-153.0026'}, 'message': 'success'}
# 2021-08-06 23:49:10.569930
#
# {'timestamp': 1628264961, 'iss_position': {'latitude': '-45.1000', 'longitude': '-152.2358'}, 'message': 'success'}
# 2021-08-06 23:49:20.921740
# {'timestamp': 1628264971, 'iss_position': {'latitude': '-44.7741', 'longitude': '-151.4399'}, 'message': 'success'}
# 2021-08-06 23:49:31.289097
#
# {'timestamp': 1628264982, 'iss_position': {'latitude': '-44.4421', 'longitude': '-150.6535'}, 'message': 'success'}
# 2021-08-06 23:49:41.668132
#
# {'timestamp': 1628264992, 'iss_position': {'latitude': '-44.1041', 'longitude': '-149.8767'}, 'message': 'success'}
# 2021-08-06 23:49:52.048179
#
# {'timestamp': 1628265002, 'iss_position': {'latitude': '-43.7753', 'longitude': '-149.1423'}, 'message': 'success'}
# 2021-08-06 23:50:02.390117
#
# {'timestamp': 1628265013, 'iss_position': {'latitude': '-43.4260', 'longitude': '-148.3836'}, 'message': 'success'}
# 2021-08-06 23:50:12.766109
#
# {'timestamp': 1628265023, 'iss_position': {'latitude': '-43.0712', 'longitude': '-147.6344'}, 'message': 'success'}
# 2021-08-06 23:50:23.128144
#
# {'timestamp': 1628265033, 'iss_position': {'latitude': '-42.7283', 'longitude': '-146.9294'}, 'message': 'success'}
# 2021-08-06 23:50:33.507193
#
# {'timestamp': 1628265044, 'iss_position': {'latitude': '-42.3630', 'longitude': '-146.1980'}, 'message': 'success'}
# 2021-08-06 23:50:43.860302
#
# {'timestamp': 1628265054, 'iss_position': {'latitude': '-41.9926', 'longitude': '-145.4758'}, 'message': 'success'}
# 2021-08-06 23:50:54.241760
#
# {'timestamp': 1628265064, 'iss_position': {'latitude': '-41.6351', 'longitude': '-144.7960'}, 'message': 'success'}
# 2021-08-06 23:51:04.588756
#
# {'timestamp': 1628265075, 'iss_position': {'latitude': '-41.2549', 'longitude': '-144.0910'}, 'message': 'success'}
# 2021-08-06 23:51:14.948962
#
# {'timestamp': 1628265085, 'iss_position': {'latitude': '-40.8699', 'longitude': '-143.3947'}, 'message': 'success'}
# 2021-08-06 23:51:25.305165
#
# {'timestamp': 1628265095, 'iss_position': {'latitude': '-40.4989', 'longitude': '-142.7396'}, 'message': 'success'}
# 2021-08-06 23:51:35.663144
#
# {'timestamp': 1628265106, 'iss_position': {'latitude': '-40.1048', 'longitude': '-142.0599'}, 'message': 'success'}
# 2021-08-06 23:51:46.050291
#
# {'timestamp': 1628265117, 'iss_position': {'latitude': '-39.7063', 'longitude': '-141.3886'}, 'message': 'success'}
# 2021-08-06 23:51:56.441025
#
# {'timestamp': 1628265127, 'iss_position': {'latitude': '-39.3033', 'longitude': '-140.7256'}, 'message': 'success'}
# 2021-08-06 23:52:06.792802
#
# {'timestamp': 1628265137, 'iss_position': {'latitude': '-38.9157', 'longitude': '-140.1018'}, 'message': 'success'}
# 2021-08-06 23:52:17.243199
#
# {'timestamp': 1628265148, 'iss_position': {'latitude': '-38.4851', 'longitude': '-139.4240'}, 'message': 'success'}
# 2021-08-06 23:52:27.603309
#
# {'timestamp': 1628265158, 'iss_position': {'latitude': '-38.0897', 'longitude': '-138.8153'}, 'message': 'success'}
# 2021-08-06 23:52:38.253621
#
# {'timestamp': 1628265169, 'iss_position': {'latitude': '-37.6707', 'longitude': '-138.1838'}, 'message': 'success'}
# 2021-08-06 23:52:48.641071
#
# {'timestamp': 1628265179, 'iss_position': {'latitude': '-37.2479', 'longitude': '-137.5599'}, 'message': 'success'}
# 2021-08-06 23:52:59.004353
#
# {'timestamp': 1628265189, 'iss_position': {'latitude': '-36.8418', 'longitude': '-136.9725'}, 'message': 'success'}
# 2021-08-06 23:53:09.360005
#
# {'timestamp': 1628265200, 'iss_position': {'latitude': '-36.4118', 'longitude': '-136.3630'}, 'message': 'success'}
# 2021-08-06 23:53:19.756622
#
# {'timestamp': 1628265210, 'iss_position': {'latitude': '-35.9783', 'longitude': '-135.7608'}, 'message': 'success'}
# 2021-08-06 23:53:30.136933
#
# {'timestamp': 1628265221, 'iss_position': {'latitude': '-35.5414', 'longitude': '-135.1657'}, 'message': 'success'}
# 2021-08-06 23:53:40.501655
#
# {'timestamp': 1628265231, 'iss_position': {'latitude': '-35.1221', 'longitude': '-134.6053'}, 'message': 'success'}
# 2021-08-06 23:53:50.883471
#
# {'timestamp': 1628265241, 'iss_position': {'latitude': '-34.6786', 'longitude': '-134.0235'}, 'message': 'success'}
# 2021-08-06 23:54:01.270833
#
# {'timestamp': 1628265252, 'iss_position': {'latitude': '-34.2320', 'longitude': '-133.4484'}, 'message': 'success'}
# 2021-08-06 23:54:11.608615
#
# {'timestamp': 1628265262, 'iss_position': {'latitude': '-33.8038', 'longitude': '-132.9068'}, 'message': 'success'}
# 2021-08-06 23:54:21.973807
#
# {'timestamp': 1628265272, 'iss_position': {'latitude': '-33.3512', 'longitude': '-132.3444'}, 'message': 'success'}
# 2021-08-06 23:54:32.353529
#
# {'timestamp': 1628265283, 'iss_position': {'latitude': '-32.8958', 'longitude': '-131.7884'}, 'message': 'success'}
# 2021-08-06 23:54:42.738908
#
# {'timestamp': 1628265293, 'iss_position': {'latitude': '-32.4375', 'longitude': '-131.2385'}, 'message': 'success'}
# 2021-08-06 23:54:53.123592
#
# {'timestamp': 1628265303, 'iss_position': {'latitude': '-31.9984', 'longitude': '-130.7203'}, 'message': 'success'}
# 2021-08-06 23:55:03.504631
#
# {'timestamp': 1628265314, 'iss_position': {'latitude': '-31.5347', 'longitude': '-130.1820'}, 'message': 'success'}
# 2021-08-06 23:55:13.885807
#
# {'timestamp': 1628265324, 'iss_position': {'latitude': '-31.0684', 'longitude': '-129.6494'}, 'message': 'success'}
# 2021-08-06 23:55:24.243493
#
# {'timestamp': 1628265334, 'iss_position': {'latitude': '-30.6220', 'longitude': '-129.1475'}, 'message': 'success'}
# 2021-08-06 23:55:34.619476
#
# {'timestamp': 1628265345, 'iss_position': {'latitude': '-30.1508', 'longitude': '-128.6259'}, 'message': 'success'}
# 2021-08-06 23:55:44.993155
#
# {'timestamp': 1628265355, 'iss_position': {'latitude': '-29.6772', 'longitude': '-128.1097'}, 'message': 'success'}
# 2021-08-06 23:55:55.393652
#
# {'timestamp': 1628265366, 'iss_position': {'latitude': '-29.2012', 'longitude': '-127.5987'}, 'message': 'success'}
# 2021-08-06 23:56:05.757370
#
# {'timestamp': 1628265376, 'iss_position': {'latitude': '-28.7458', 'longitude': '-127.1168'}, 'message': 'success'}
# 2021-08-06 23:56:16.149322
#
# {'timestamp': 1628265387, 'iss_position': {'latitude': '-28.2655', 'longitude': '-126.6157'}, 'message': 'success'}
# 2021-08-06 23:56:26.506019
#
# {'timestamp': 1628265397, 'iss_position': {'latitude': '-27.7830', 'longitude': '-126.1196'}, 'message': 'success'}
# 2021-08-06 23:56:36.854001
#
# {'timestamp': 1628265407, 'iss_position': {'latitude': '-27.3215', 'longitude': '-125.6514'}, 'message': 'success'}
# 2021-08-06 23:56:47.235433
#
# {'timestamp': 1628265418, 'iss_position': {'latitude': '-26.8349', 'longitude': '-125.1645'}, 'message': 'success'}
# 2021-08-06 23:56:57.586164
#
# {'timestamp': 1628265428, 'iss_position': {'latitude': '-26.3464', 'longitude': '-124.6821'}, 'message': 'success'}
# 2021-08-06 23:57:07.972429
#
# {'timestamp': 1628265438, 'iss_position': {'latitude': '-25.8793', 'longitude': '-124.2267'}, 'message': 'success'}
# 2021-08-06 23:57:18.321957
#
# {'timestamp': 1628265449, 'iss_position': {'latitude': '-25.3870', 'longitude': '-123.7528'}, 'message': 'success'}
# 2021-08-06 23:57:28.682866
#
# {'timestamp': 1628265459, 'iss_position': {'latitude': '-24.8929', 'longitude': '-123.2831'}, 'message': 'success'}
# 2021-08-06 23:57:39.041157
#
# {'timestamp': 1628265470, 'iss_position': {'latitude': '-24.3971', 'longitude': '-122.8174'}, 'message': 'success'}
# 2021-08-06 23:57:49.429152
#
# {'timestamp': 1628265480, 'iss_position': {'latitude': '-23.9233', 'longitude': '-122.3777'}, 'message': 'success'}
# 2021-08-06 23:57:59.819923
#
# {'timestamp': 1628265490, 'iss_position': {'latitude': '-23.4242', 'longitude': '-121.9198'}, 'message': 'success'}
# 2021-08-06 23:58:10.178716
#
# {'timestamp': 1628265501, 'iss_position': {'latitude': '-22.9235', 'longitude': '-121.4657'}, 'message': 'success'}
# 2021-08-06 23:58:20.533939
#
# {'timestamp': 1628265511, 'iss_position': {'latitude': '-22.4452', 'longitude': '-121.0366'}, 'message': 'success'}
# 2021-08-06 23:58:30.911828
#
# {'timestamp': 1628265521, 'iss_position': {'latitude': '-21.9415', 'longitude': '-120.5895'}, 'message': 'success'}
# 2021-08-06 23:58:41.277762
#
# {'timestamp': 1628265532, 'iss_position': {'latitude': '-21.4363', 'longitude': '-120.1459'}, 'message': 'success'}
# 2021-08-06 23:58:51.643808
#
# {'timestamp': 1628265542, 'iss_position': {'latitude': '-20.9539', 'longitude': '-119.7265'}, 'message': 'success'}
# 2021-08-06 23:59:02.037725
#
# {'timestamp': 1628265552, 'iss_position': {'latitude': '-20.4460', 'longitude': '-119.2894'}, 'message': 'success'}
# 2021-08-06 23:59:12.391811
# {'timestamp': 1628265563, 'iss_position': {'latitude': '-19.9369', 'longitude': '-118.8555'}, 'message': 'success'}
# 2021-08-06 23:59:22.775823

# %% [markdown]
# ### 2.2
#
# Using the data you gathered and stored in `iss-data.json`, make a `matplotlib` plot of the location data.
#
# The specifications of this problem are as follows:
# 1. Use the longitude and latitude data contained in `iss-data.json` as your data.
# 2. Plot this data on a `matplotlib` plot that appropriately visualizes the data. It is up to you what specific plot you want to use as long as we, the human readers of your report, understand the message of your plot.
# 3. Use latitude as the X axis and longitude as the Y axis.
# 4. VERY IMPORTANT: Make sure that the chart displays in your Jupyter notebook before you submit.
#
# We will only check the chart. We do not care how you make it display as long as you follow the specifications.

# %%
# CODE CELL

# CODE START
import json
import matplotlib.pyplot as plt
import numpy as np
iss_data = []
with open('iss-data.json', 'r') as f:
    iss_data = json.load(f)
x_axis = []
y_axis = []

for position in iss_data:
    x_axis.append(float(position['iss_position']['latitude']))
    y_axis.append(float(position['iss_position']['longitude']))
    
plt.xlabel("Latitude")
plt.ylabel("Longitude")
plt.title('ISS Scatter Plot')
plt.scatter(x_axis, y_axis)
plt.show()
# CODE END
